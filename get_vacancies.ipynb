# %%
def get_vacancy_skills(vacancy_id):
    url = f'https://api.hh.ru/vacancies/{vacancy_id}'

    response = requests.get(url)
    response.raise_for_status()
    data = response.json()

    skills = [skill['name'] for skill in data.get('key_skills', [])]
    if not skills:
            return "Не указано"
    else:
        return ', '.join(skills)

# %%
import requests
import pandas as pd
from datetime import datetime

def get_vacancy_skills(vacancy_id):
    """
    Получает список навыков для указанной вакансии.

    Args:
        vacancy_id: ID вакансии.

    Returns:
        Список навыков (строк).  Возвращает пустой список в случае ошибки.
    """

    url = f"https://api.hh.ru/vacancies/{vacancy_id}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        skills = [skill["name"] for skill in data.get("key_skills", [])]
        return skills
    else:
        print(f"Ошибка при получении навыков для вакансии {vacancy_id}: {response.status_code}, {response.text}")
        return []

def search_vacancies(text="", area=1, max_vacancies=1):
    """
    Ищет вакансии с указанием текста и региона.

    Args:
        text: Текст для поиска в вакансиях.
        area: ID региона.

    Returns:
        Кортеж: (vacancies_data, skills_list)
            vacancies_Список словарей с информацией о вакансиях.
            skills_list: Список словарей с навыками для каждой вакансии.
    """
    url = "https://api.hh.ru/vacancies"
    params = {
        "text": text,
        "area": area,
        "per_page": 100  # Максимальное количество вакансий на странице (можно менять)
    }
    vacancies_data = []  # Список для хранения информации о вакансиях
    skills_list = [] # Список для хранения скиллов
    total_vacancies = 0 # Счетчик извлеченных вакансий
    page = 0
    while True: #Перебираем все страницы
        params["page"] = page
        response = requests.get(url, params=params)
        if response.status_code == 200:
            data = response.json()
            items = data.get("items", [])  # Получаем список вакансий с текущей страницы

            if not items:  # Если вакансий на странице нет, выходим из цикла
                break

            for item in items:
                published_at = item["published_at"]
                try:
                   published_at_formatted = datetime.fromisoformat(published_at.replace('Z', '+00:00')).strftime('%Y-%m-%d %H:%M')
                except ValueError:
                    published_at_formatted = 'Не указано'

                vacancy_info = {
                    "id": item["id"],
                    "name": item["name"],
                    "employer": item["employer"]["name"],
                    "salary_from": item["salary"]["from"] if item["salary"] and item["salary"].get("from") else 'Не указано',
                    "experience": item["experience"]["name"] if "experience" in item else 'Не указано',
                    "description": item.get("snippet", {}).get("requirement", 'Не указано'), # Используем snippet для краткого описания
                    "published_at": published_at_formatted,
                }

                skills_for_vacancy = get_vacancy_skills(item['id']) # Получаем список навыков для вакансии
                for skill in skills_for_vacancy:
                  skills_list.append({"vacancy_id": item["id"], "skill": skill}) # Записываем в skills_list каждый скил отдельной строкой.

                vacancies_data.append(vacancy_info)
                total_vacancies += 1 # Инкрементируем счетчик

            if total_vacancies >= max_vacancies: # Проверяем лимит и выходим из цикла pages
                break

            page += 1

            if page >= data.get("pages", 1):  # Если текущая страница последняя, выходим из цикла
                break

        else:
            print(f"Ошибка при запросе: {response.status_code}, {response.text}")
            return [], [] # Возвращаем пустые списки в случае ошибки

    return vacancies_data, skills_list


# Пример использования:
if __name__ == '__main__':
    text = ['data engineer', 'gamedev', 'java', '.net', 'реклама', 'маркетинг']
    df_vacancy = pd.DataFrame()
    df_vacancy_skills = pd.DataFrame()

    for i in text:
        vacancies, skills = search_vacancies(
            text=i,
            area=[1,2,22],
            max_vacancies=1,
        )

        if vacancies:
            df_vacancy = pd.concat([df_vacancy, pd.DataFrame(vacancies)], ignore_index=True)
        if skills:
            df_vacancy_skills = pd.concat([df_vacancy_skills, pd.DataFrame(skills)], ignore_index=True)

    print("DataFrame с вакансиями:")
    print(df_vacancy.head())

    print("\nDataFrame с навыками:")
    print(df_vacancy_skills.head())
# Out:
# Ошибка при получении навыков для вакансии 118469860: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYAKdo0Xt38LgKJ5fyfbA5Pw%3D","type":"captcha_required"}],"request_id":"17424389485745248c34705d7e44148f"}
# Ошибка при получении навыков для вакансии 118549505: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYPJ9HmskBRDxW5ndIh1MdBc%3D","type":"captcha_required"}],"request_id":"17424389489340df3a267fb6ad9c0f7a"}
# Ошибка при получении навыков для вакансии 118432324: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYIdP_2u1LP4Az1-FVTzC7cA%3D","type":"captcha_required"}],"request_id":"17424389493066fae86d442576ab5056"}
# Ошибка при получении навыков для вакансии 118339641: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYFexv2eaXSpN4oc6HtnqgEc%3D","type":"captcha_required"}],"request_id":"174243894968720bb9945c7f744d50d0"}
# Ошибка при получении навыков для вакансии 117114151: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYHs9GWNMXtN3F8NKqSGndHc%3D","type":"captcha_required"}],"request_id":"1742438950102927778fe96a99262d44"}
# Ошибка при получении навыков для вакансии 118289630: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYOc2VULwQsRE8bwWhhIBdug%3D","type":"captcha_required"}],"request_id":"17424389505206ea1ef1c4aa59caf338"}
# Ошибка при получении навыков для вакансии 118457477: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYO-quk4XSrBxNGKuMu2m77w%3D","type":"captcha_required"}],"request_id":"1742438950883812d9e88f28170ca607"}
# Ошибка при получении навыков для вакансии 117615311: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBq2DcFuA4eV3HspAHvjsL0%3D","type":"captcha_required"}],"request_id":"17424389512897b839d7118c973e7a3d"}
# Ошибка при получении навыков для вакансии 117743231: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYNxdKasNQJiEo233LLTa_UI%3D","type":"captcha_required"}],"request_id":"174243895259077bd158cd244356d812"}
# Ошибка при получении навыков для вакансии 118572436: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYFBuVqf4AsQIYZdKHkp3SlI%3D","type":"captcha_required"}],"request_id":"17424389530040439aeacab6d06aced3"}
# Ошибка при получении навыков для вакансии 118520623: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYA_Z313W3aQ-YlOGhuznrbE%3D","type":"captcha_required"}],"request_id":"1742438954200a5f0716d714c3ba86f1"}
# Ошибка при получении навыков для вакансии 118456459: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYPnBtCEkeWCyiOjjaaFjM94%3D","type":"captcha_required"}],"request_id":"17424389554506f0fc0b1a22bab3cc41"}
# Ошибка при получении навыков для вакансии 118266393: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYN2kpyJJsD8R56cB7HwWkZs%3D","type":"captcha_required"}],"request_id":"1742438955844ddc5843c9f23a2cb440"}
# Ошибка при получении навыков для вакансии 118312325: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYB_NCavAY9jNaWZnFhPny2U%3D","type":"captcha_required"}],"request_id":"174243895621308d385b5f7c8ff2cbd1"}
# Ошибка при получении навыков для вакансии 117414384: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYLxNAvK7H2fCocmy8ZXWWGs%3D","type":"captcha_required"}],"request_id":"17424389566070fdb5a91edd1875553c"}
# Ошибка при получении навыков для вакансии 118205636: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYIMUaHRb6ez_153YsMr-LdY%3D","type":"captcha_required"}],"request_id":"174243895701028bde2c197b5c7012cf"}
# Ошибка при получении навыков для вакансии 118007819: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYME4Qdhe2uB_6mtaxK2NSBM%3D","type":"captcha_required"}],"request_id":"17424389573659e43896579928eea8d2"}
# Ошибка при получении навыков для вакансии 118328508: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYI6SjBnM6osPDueg9uazPRE%3D","type":"captcha_required"}],"request_id":"1742438957772ef06d77bca5ad9a5a6f"}
# Ошибка при получении навыков для вакансии 116391375: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYDFC2RP1Xl45LB5NlvHPne8%3D","type":"captcha_required"}],"request_id":"17424389581533af9404c21a2dd85cdd"}
# Ошибка при получении навыков для вакансии 118431186: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBJ46nP08aEDW4MiChwg-XQ%3D","type":"captcha_required"}],"request_id":"1742438958543b3a61c5661acaef688d"}
# Ошибка при получении навыков для вакансии 118563849: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYHq_17Y30pSOeT0TSes2eqE%3D","type":"captcha_required"}],"request_id":"1742438958934cb2e4397ce0d16d4adc"}
# Ошибка при получении навыков для вакансии 117775765: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYB8mkzg-odx0Y74lljvOX3A%3D","type":"captcha_required"}],"request_id":"17424389592999756ce7f9bf05ccdc3c"}
# Ошибка при получении навыков для вакансии 118457832: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYFHzrW-MuPPd9XXnvKP9Cuc%3D","type":"captcha_required"}],"request_id":"1742438959671f90a9aa958d9a4bbdfe"}
# Ошибка при получении навыков для вакансии 117983881: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYAgb4LkKitNUX6zyW2AaAlo%3D","type":"captcha_required"}],"request_id":"17424389600869ffeda05f6ea0e0cdc8"}
# Ошибка при получении навыков для вакансии 118424896: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYHZsb7nJoUl6wb8GzfYjN7k%3D","type":"captcha_required"}],"request_id":"17424389608468cfae5cec749d1198cb"}
# Ошибка при получении навыков для вакансии 118021923: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBdUPjgQRsVJawkBkcW4H-A%3D","type":"captcha_required"}],"request_id":"1742438961234e8d5ba74231e0fd80d6"}
# Ошибка при получении навыков для вакансии 117996879: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYIRdqCskHf9BHpyQbPdMDAw%3D","type":"captcha_required"}],"request_id":"174243896160915ba5ab3f95e1471d83"}
# Ошибка при получении навыков для вакансии 118206390: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYIUSiYRZF31QhRWm2Bv6HjM%3D","type":"captcha_required"}],"request_id":"17424389620317f67eb40743fed131f0"}
# Ошибка при получении навыков для вакансии 117547532: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYMWkNwKW9vLi5vjLiRCki1U%3D","type":"captcha_required"}],"request_id":"174243896240435f4c15b7f42c919301"}
# Ошибка при получении навыков для вакансии 117447780: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYE2jPeqaXwDWlWy3Ko7zrQA%3D","type":"captcha_required"}],"request_id":"1742438962790c3911c374bfe4e59c32"}
# Ошибка при получении навыков для вакансии 118197911: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYNIrS6hKVzMekMXv9a1RTpg%3D","type":"captcha_required"}],"request_id":"174243896322954824202319762c030f"}
# Ошибка при получении навыков для вакансии 117902253: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYB04EU9UJCDS5qUruNFzVeo%3D","type":"captcha_required"}],"request_id":"1742438963604e9e9ae0e1cb2fc3d3dd"}
# Ошибка при получении навыков для вакансии 118489086: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYIw_xtvpDJX3KBD6jFuFa20%3D","type":"captcha_required"}],"request_id":"174243896401524a7a5639e34b0b2c15"}
# Ошибка при получении навыков для вакансии 118490102: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYE51P2eV5OpHVsL0sboanzQ%3D","type":"captcha_required"}],"request_id":"174243896438527238a523d99f9bd9b8"}
# Ошибка при получении навыков для вакансии 118520505: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYNYT5CxUJWPgEA2ftJfYzuM%3D","type":"captcha_required"}],"request_id":"1742438964753346c2a0b14d7e085ffd"}
# Ошибка при получении навыков для вакансии 118311956: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYF_NoG04mfN2mfX0ux5T3fE%3D","type":"captcha_required"}],"request_id":"17424389651298c4cfe289e80cea6ea1"}
# Ошибка при получении навыков для вакансии 117821657: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYD4znvYHGa51xUco8vCbBSo%3D","type":"captcha_required"}],"request_id":"1742438965539f2d8d7092effa2061b0"}
# Ошибка при получении навыков для вакансии 118471691: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYMNwm3y-dG4Z8ZGO_laWOdw%3D","type":"captcha_required"}],"request_id":"1742438965959cd17f2d9083d64e61bd"}
# Ошибка при получении навыков для вакансии 118316114: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYPL-bYPrCGiMJSnmFQ8MzSo%3D","type":"captcha_required"}],"request_id":"17424389664015fd0c4d785f333eba02"}
# Ошибка при получении навыков для вакансии 117490641: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYOlDMnjwIvjTt3aQp54c7V4%3D","type":"captcha_required"}],"request_id":"17424389668463f33a2af3089bfffffb"}
# Ошибка при получении навыков для вакансии 110103237: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYEd6h3gfjcBe5nFN79CxN_c%3D","type":"captcha_required"}],"request_id":"17424389672922a893cb4cd6b12a4363"}
# Ошибка при получении навыков для вакансии 118243234: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYPtKzww4S2WEuT-zp92uO5w%3D","type":"captcha_required"}],"request_id":"1742438967677c06011a1d8d01a86b08"}
# Ошибка при получении навыков для вакансии 117917804: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYPthp9QEQs_qLjySLNbTzz8%3D","type":"captcha_required"}],"request_id":"1742438968096c5d2496bc5c7f4ff531"}
# Ошибка при получении навыков для вакансии 117512865: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYFHhAE5ceOwK3th1kWjgEIU%3D","type":"captcha_required"}],"request_id":"174243896886872c4f7bf694f62b10d8"}
# Ошибка при получении навыков для вакансии 118292149: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYLcqrtat6gu0cn0inCMixuQ%3D","type":"captcha_required"}],"request_id":"1742438969276f057bde45e271b0b968"}
# Ошибка при получении навыков для вакансии 118079938: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYGFwUj0S-MRewSCFttTtvqM%3D","type":"captcha_required"}],"request_id":"1742438969648b5d75ae06dc4e3f877f"}
# Ошибка при получении навыков для вакансии 118485153: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYCYmqAulhOPn2D9pCKpq7ok%3D","type":"captcha_required"}],"request_id":"1742438970033e499530d7b609393d6e"}
# Ошибка при получении навыков для вакансии 117944191: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYNxDkFugzMhZShYVJA7Eskc%3D","type":"captcha_required"}],"request_id":"1742438970400d2604240222a479ad9f"}
# Ошибка при получении навыков для вакансии 118260579: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYK9aWk1q3iJgyEIoV-IHPw0%3D","type":"captcha_required"}],"request_id":"1742438970796119819f9cd745019802"}
# Ошибка при получении навыков для вакансии 117672033: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYOYLFPuT4joxPFTEEQwSLl0%3D","type":"captcha_required"}],"request_id":"17424389712340527a677e8d8d6c72ea"}
# Ошибка при получении навыков для вакансии 117687922: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYKOCRAKvE1FZLsQHYvRK3MI%3D","type":"captcha_required"}],"request_id":"1742438971653e4db96db38c8e26f992"}
# Ошибка при получении навыков для вакансии 118436867: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYCgDZ53FHUSGqz9OgprENiw%3D","type":"captcha_required"}],"request_id":"17424389720391ba5db7ff2febef179d"}
# Ошибка при получении навыков для вакансии 117628363: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYEO0Izsge0d31CjSA4pNQhg%3D","type":"captcha_required"}],"request_id":"1742438972831de7bcc41b7136339d54"}
# Ошибка при получении навыков для вакансии 117839880: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYMU786yK_u-EvSzlMEDBq0U%3D","type":"captcha_required"}],"request_id":"17424389732063efe1c0cce007268550"}
# Ошибка при получении навыков для вакансии 118047738: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYOzjBIp1Wf0coZ2ps__g3rk%3D","type":"captcha_required"}],"request_id":"1742438973622077fc935428c853aeaa"}
# Ошибка при получении навыков для вакансии 117748915: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYLSOgLWqo4RYcdDgyv_Y5mA%3D","type":"captcha_required"}],"request_id":"1742438974020cc8e2b0109e90978d30"}
# Ошибка при получении навыков для вакансии 117835527: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYNe0MiVNx-rxt8RfCs88FYs%3D","type":"captcha_required"}],"request_id":"17424389744260c143990a0b7284f346"}
# Ошибка при получении навыков для вакансии 118256962: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYGNAzLGm24DsRdMJj4pJoo0%3D","type":"captcha_required"}],"request_id":"17424389748194e85fd780f7236e875d"}
# Ошибка при получении навыков для вакансии 117652857: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYOfz3HxI_oaI5kVX87jXPto%3D","type":"captcha_required"}],"request_id":"1742438975236d02237003ed1b04d9f5"}
# Ошибка при получении навыков для вакансии 110253961: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYGAT7WiPR1v80r24F4nUuus%3D","type":"captcha_required"}],"request_id":"1742438976054b5b519ce7d47145bdf0"}
# Ошибка при получении навыков для вакансии 117472870: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYI2akPttnW_lcCzXsjDukdw%3D","type":"captcha_required"}],"request_id":"1742438977255867f8b7202456963926"}
# Ошибка при получении навыков для вакансии 117426447: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYKjigvq8dOGb1oug8N42hHE%3D","type":"captcha_required"}],"request_id":"1742438978044da317ecb823d69714bb"}
# Ошибка при получении навыков для вакансии 118025567: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYOOM4bFLxcuIfbg6HoHMFkc%3D","type":"captcha_required"}],"request_id":"1742438978481a15acfdfd1e68fb9ebc"}
# Ошибка при получении навыков для вакансии 117571088: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYDuG57fzfNVmTMvHZYp6EHg%3D","type":"captcha_required"}],"request_id":"17424389789002a113d7ceac3ad96350"}
# Ошибка при получении навыков для вакансии 117700811: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYDnsSEWiufWw4evTCm_hPLQ%3D","type":"captcha_required"}],"request_id":"174243897932144969f7c843b2635a08"}
# Ошибка при получении навыков для вакансии 118434426: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYPD2bbOdIM1RK7Jprfuic7E%3D","type":"captcha_required"}],"request_id":"1742438979709bfee22159dba6805154"}
# Ошибка при получении навыков для вакансии 116461252: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYMUzJSq5T5C1itaJRYKoAuE%3D","type":"captcha_required"}],"request_id":"17424389801213b70fbeec69d44b544a"}
# Ошибка при получении навыков для вакансии 117684890: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYGxIm-U5aNGsG7ZTa8TZVGw%3D","type":"captcha_required"}],"request_id":"1742438980558087b5256174ea072bc4"}
# Ошибка при получении навыков для вакансии 118574678: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYDzS3CC8D1O4ylO18mzdP5s%3D","type":"captcha_required"}],"request_id":"1742438981765965d19e716804d9372d"}
# Ошибка при получении навыков для вакансии 118569708: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYD6DkSR865nZCXNJkNQrlIc%3D","type":"captcha_required"}],"request_id":"1742438982163bde8684544fedd57cd2"}
# Ошибка при получении навыков для вакансии 118499449: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYK3x4ibfjx2UUQdah5oVoKc%3D","type":"captcha_required"}],"request_id":"17424389833715157243fc57f0842b0c"}
# Ошибка при получении навыков для вакансии 118362790: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYNVYJi-RHwGqlIyLRR62MMQ%3D","type":"captcha_required"}],"request_id":"174243898438521cb72c913a336c60fb"}
# Ошибка при получении навыков для вакансии 118508052: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYIbOrr3TXEzWzLQwqdNkBhQ%3D","type":"captcha_required"}],"request_id":"17424389863256ad9bb3db0ce012b0c5"}
# Ошибка при получении навыков для вакансии 118557885: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYDAoI2uPq6RyHlc_k2Z1AJA%3D","type":"captcha_required"}],"request_id":"17424389871283579c00a7a570d6c583"}
# Ошибка при получении навыков для вакансии 118330562: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYNPOp4e2pGDtIIqV87kxUvU%3D","type":"captcha_required"}],"request_id":"17424389880381e4ecb296e3b0612d12"}
# Ошибка при получении навыков для вакансии 118466650: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYPg9fZ59HTqThuNzzhVLDSo%3D","type":"captcha_required"}],"request_id":"17424389892369e9fada554bfbb07e3f"}
# Ошибка при получении навыков для вакансии 118497533: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYFHESZ-BrrvzoAks65bCZd4%3D","type":"captcha_required"}],"request_id":"17424389896254f606affff4aff78467"}
# Ошибка при получении навыков для вакансии 118348961: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYEsY4eeqClt1Am8RPAUXZus%3D","type":"captcha_required"}],"request_id":"1742438990023f6aa20167773b924127"}
# Ошибка при получении навыков для вакансии 118185786: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYP0CehDNsz17W-MJyPHldoo%3D","type":"captcha_required"}],"request_id":"1742438990470e8eeccfda5b358d986b"}
# Ошибка при получении навыков для вакансии 117384100: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYP4XnnCA3QOlTCd8pqYYAsk%3D","type":"captcha_required"}],"request_id":"1742438990863865dae496e379158dda"}
# Ошибка при получении навыков для вакансии 118423765: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYHbCpV5mWJrVES9al7pxbQ8%3D","type":"captcha_required"}],"request_id":"1742438991242f15a0bdd4e255b99b0d"}
# Ошибка при получении навыков для вакансии 117705764: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYAKzrMbf9sXM2jk38lswHf8%3D","type":"captcha_required"}],"request_id":"174243899163069b3e8b507bb7e4c213"}
# Ошибка при получении навыков для вакансии 118361814: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYMXkwiR53_uIvItHjLb_60g%3D","type":"captcha_required"}],"request_id":"17424389920445eb78bc0b63dc83c928"}
# Ошибка при получении навыков для вакансии 117841164: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYEVb93lwc8Ask_Qf0WnAf0o%3D","type":"captcha_required"}],"request_id":"174243899281345bb590f325e386a745"}
# Ошибка при получении навыков для вакансии 118429508: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYMHwOyn-nuIpBKqoPajXuOo%3D","type":"captcha_required"}],"request_id":"17424389932296d82afd0a8a7ab7a7e3"}
# Ошибка при получении навыков для вакансии 118432313: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYJq9H5pICp5GWp_gT_PJ-Bc%3D","type":"captcha_required"}],"request_id":"17424389935982cb29d18dc50accb1b5"}
# Ошибка при получении навыков для вакансии 118554162: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYFwHVhDldv0joMuUGn97ZGw%3D","type":"captcha_required"}],"request_id":"17424389939698c6f35e25b9e1bd235f"}
# Ошибка при получении навыков для вакансии 118524065: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYNbOSeYXMGD35QRk6yyoCfc%3D","type":"captcha_required"}],"request_id":"17424389943374f49ed9529920fe528f"}
# Ошибка при получении навыков для вакансии 118494088: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBBSRE90Zq44EnTNeXN8QPk%3D","type":"captcha_required"}],"request_id":"174243899507401da13d706387373fbc"}
# Ошибка при получении навыков для вакансии 118314408: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYDB8vB6DTURvFC0oBkd7TH8%3D","type":"captcha_required"}],"request_id":"174243899584416db7da8ff02299da9d"}
# Ошибка при получении навыков для вакансии 118467153: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYJsz8bzeVH8cDKEJIESpE9I%3D","type":"captcha_required"}],"request_id":"1742438996217fd0f63a28155e5a6442"}
# Ошибка при получении навыков для вакансии 118545912: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYK7jRXgO3piyJ27-I9JmBxc%3D","type":"captcha_required"}],"request_id":"1742438999267c73bb2ebf5f3d8f24d3"}
# Ошибка при получении навыков для вакансии 118536640: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYB5bcGM-CEhGe5lNku8BUVE%3D","type":"captcha_required"}],"request_id":"17424389996733765f3a8339d191099b"}
# Ошибка при получении навыков для вакансии 118454583: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYASCmBV5uHFJi6Am647ZeIg%3D","type":"captcha_required"}],"request_id":"17424390000922d7cedb67e6f5fae6c5"}
# Ошибка при получении навыков для вакансии 118546881: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYHVCfmcvo0PSAXNBCb52a88%3D","type":"captcha_required"}],"request_id":"17424390004847922bd97df9d2c81d46"}
# Ошибка при получении навыков для вакансии 118507530: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBfistWYmJ1ruNRPRKA1Ib8%3D","type":"captcha_required"}],"request_id":"17424390008472fbedeb47b218acc2e1"}
# Ошибка при получении навыков для вакансии 118548965: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYEj9Ov7aUXVgocXC1Mocp1I%3D","type":"captcha_required"}],"request_id":"1742439001262c6bb2e75e5d4b3fe723"}
# Ошибка при получении навыков для вакансии 118299063: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYJ1Y1iry7zYr7NCvjC2yzfE%3D","type":"captcha_required"}],"request_id":"174243900204100ec1260667a1c209ce"}
# Ошибка при получении навыков для вакансии 118422736: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYGwaZ3DhYW-_nDd07bX8QNg%3D","type":"captcha_required"}],"request_id":"1742439003229d58d1c7cc5aabdacfaf"}
# Ошибка при получении навыков для вакансии 118003761: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYHKtlJhPcNX8Kecd9lfkyx4%3D","type":"captcha_required"}],"request_id":"1742439003999dd32ed156fe1bce8552"}
# Ошибка при получении навыков для вакансии 118525511: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYGNKySmbhHgUWkDPoCdv_Yk%3D","type":"captcha_required"}],"request_id":"17424390047740b20fa9eb3bc534ba69"}
# Ошибка при получении навыков для вакансии 118451851: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBX__PQbnRnVLt4tvC0-Uo0%3D","type":"captcha_required"}],"request_id":"1742439005160a99613770357f02f987"}
# Ошибка при получении навыков для вакансии 117495165: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYDNKT2aQYqb3jnE3zbb2D90%3D","type":"captcha_required"}],"request_id":"1742439006324e5be756c22a42b50fa4"}
# Ошибка при получении навыков для вакансии 118535790: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYM8Mg-CMEQLJjvNub0mPeX0%3D","type":"captcha_required"}],"request_id":"1742439007099eec558bcbb7a743632e"}
# Ошибка при получении навыков для вакансии 118544016: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYJzreOO-12wiPAXVJKTRB1g%3D","type":"captcha_required"}],"request_id":"17424390083475227088e5c0dac65141"}
# Ошибка при получении навыков для вакансии 118276457: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYK37EUu5ApDslrLzR7DlH2M%3D","type":"captcha_required"}],"request_id":"1742439009151599489e9cad0f344b30"}
# Ошибка при получении навыков для вакансии 118491385: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYLSHifq6WRPMm0uKmwpVmYI%3D","type":"captcha_required"}],"request_id":"17424390095656d9ca0b0f6baef0bd6c"}
# Ошибка при получении навыков для вакансии 118445271: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYOc9ndqgiAf5yzdWmPPVc10%3D","type":"captcha_required"}],"request_id":"174243900995434b14bbffbceeb729e4"}
# Ошибка при получении навыков для вакансии 117083569: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYPEo4PqHu2cHJ3BS7qsW6vY%3D","type":"captcha_required"}],"request_id":"1742439010327f2a3fdf1beae131353e"}
# Ошибка при получении навыков для вакансии 117750017: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYGZhqOhJ8RzErX31NoL01Ew%3D","type":"captcha_required"}],"request_id":"1742439010718a26b4f793e52a57fe39"}
# Ошибка при получении навыков для вакансии 118465919: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYOWHlY4tTFO_w5xYpva4SMk%3D","type":"captcha_required"}],"request_id":"17424390111522e48455e707bf8fb356"}
# Ошибка при получении навыков для вакансии 109239766: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYHH23ScjX2gbl-9irtd3ozY%3D","type":"captcha_required"}],"request_id":"174243901155373f9ca844fa1db80d6e"}
# Ошибка при получении навыков для вакансии 118416373: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYDHOaAGbFACNp6b4ly10MmU%3D","type":"captcha_required"}],"request_id":"174243901197666a2c805569914b020f"}
# Ошибка при получении навыков для вакансии 118449210: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYI3ylrQSDeavGInUwO5gBuM%3D","type":"captcha_required"}],"request_id":"1742439012399053f2c08d418bcac804"}
# Ошибка при получении навыков для вакансии 118497348: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYCCVZJVSX8PTqQR6fMeo79I%3D","type":"captcha_required"}],"request_id":"174243901278302faae8ea20a5ed074f"}
# Ошибка при получении навыков для вакансии 118351670: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYM8ZE_UjxFjAObOITnA06g4%3D","type":"captcha_required"}],"request_id":"1742439013170128431d8b47eefdb818"}
# Ошибка при получении навыков для вакансии 117728128: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYOiBDAJIE7gaXAd6dFC52Zc%3D","type":"captcha_required"}],"request_id":"1742439013932a915672e845858f336f"}
# Ошибка при получении навыков для вакансии 117135188: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYAyFqqfqbH53smTwR7nLX9E%3D","type":"captcha_required"}],"request_id":"174243901432621718034c45ece97c79"}
# Ошибка при получении навыков для вакансии 117825550: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYOZqHO9QVw1-gm2kfyMP4DU%3D","type":"captcha_required"}],"request_id":"1742439015119d42229b178376deea32"}
# Ошибка при получении навыков для вакансии 118479196: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYNBjDd7g7b7vtePEgLNBjRU%3D","type":"captcha_required"}],"request_id":"174243901549113370442a7ba9926837"}
# Ошибка при получении навыков для вакансии 117147926: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYAug2OwdsEdbO3yIzI39DMs%3D","type":"captcha_required"}],"request_id":"17424390159629efe34f11d5fc324ab1"}
# Ошибка при получении навыков для вакансии 118374323: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYDToptf5oyJf-7PF09jIP1Y%3D","type":"captcha_required"}],"request_id":"1742439016390fe3f7681e94185eebe9"}
# Ошибка при получении навыков для вакансии 118340781: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYAW1y-eIOsUecKgNJq_-XkY%3D","type":"captcha_required"}],"request_id":"17424390167830b1ae36ca2ff3f47afc"}
# Ошибка при получении навыков для вакансии 117466156: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYE9jXg2KFZbKHgCPBfaogoM%3D","type":"captcha_required"}],"request_id":"17424390171954d3d6eaf55eda3f44e8"}
# Ошибка при получении навыков для вакансии 118360242: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYJeWPeQhwylA-_BnWWHhJFw%3D","type":"captcha_required"}],"request_id":"174243901760819b5cd5c8c67033cfe2"}
# Ошибка при получении навыков для вакансии 117698634: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYJ0lZ6fWiEEvUXy4ABpIYD4%3D","type":"captcha_required"}],"request_id":"1742439018006c69709d04e5d1229c5c"}
# Ошибка при получении навыков для вакансии 118072483: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYEPeuJwYm9Jero4lWpOJEZI%3D","type":"captcha_required"}],"request_id":"17424390184518c88b85b2194a0c0f53"}
# Ошибка при получении навыков для вакансии 118348314: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYAiWSmFOa51Ib80NIzXDvWI%3D","type":"captcha_required"}],"request_id":"1742439018860c8dd606f25224bf1fcc"}
# Ошибка при получении навыков для вакансии 118472337: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYB8SH7MqfjYFfRgLNc8zmhU%3D","type":"captcha_required"}],"request_id":"1742439019278f907f98392bfb116379"}
# Ошибка при получении навыков для вакансии 117391993: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYOkbyRmDn5T2p-XlTasLipo%3D","type":"captcha_required"}],"request_id":"1742439019649e233555156355ca1769"}
# Ошибка при получении навыков для вакансии 118512699: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYGIbR9LfriS8uypsEpBvZCs%3D","type":"captcha_required"}],"request_id":"174243902004388ae4d5dc5a551ac646"}
# Ошибка при получении навыков для вакансии 118313507: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYG2tKCBrKqpO_lO5saP3p-Q%3D","type":"captcha_required"}],"request_id":"1742439020855e10d914be78cc7124cf"}
# Ошибка при получении навыков для вакансии 118359903: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYNOu_LR84gtQQKVFFQT62Go%3D","type":"captcha_required"}],"request_id":"17424390213261124a5166d96540dc23"}
# Ошибка при получении навыков для вакансии 118072230: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYGcvgvEVQguM4OzvM8fgnMc%3D","type":"captcha_required"}],"request_id":"17424390217225ad69f664fc9a3c58b8"}
# Ошибка при получении навыков для вакансии 118314849: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYFRHGaVI_LVdQM6xwtURjfg%3D","type":"captcha_required"}],"request_id":"17424390221337e0bdd307a0c3570df7"}
# Ошибка при получении навыков для вакансии 118457747: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYJ5LFL5xgI3m4vKBkmsYt6A%3D","type":"captcha_required"}],"request_id":"1742439022604494e1b75c79217dfebb"}
# Ошибка при получении навыков для вакансии 118250509: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYAKaddSX2gW-ifUP1ayjEqs%3D","type":"captcha_required"}],"request_id":"1742439022977e3e9677694aa2de5225"}
# Ошибка при получении навыков для вакансии 118573397: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYKo2JXMIP8wrYBaxBAq2uOo%3D","type":"captcha_required"}],"request_id":"1742439024084a4626dd317e77de37ac"}
# Ошибка при получении навыков для вакансии 118362790: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYMpZPw8K4NG3eas6NQhxvsM%3D","type":"captcha_required"}],"request_id":"174243902447387b4d4819d8da937db5"}
# Ошибка при получении навыков для вакансии 118462116: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYIi0DsoMxNfMGbn3Cn_0wSg%3D","type":"captcha_required"}],"request_id":"17424390248597c880d6d4069b277e2c"}
# Ошибка при получении навыков для вакансии 118281197: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBLRvorVersYTzi6Ug-d-y8%3D","type":"captcha_required"}],"request_id":"17424390252380815be9afa725e6ce85"}
# Ошибка при получении навыков для вакансии 118547392: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYMYHJlSGoLklNJFRSAF2dos%3D","type":"captcha_required"}],"request_id":"1742439025634b12728754be39dd342c"}
# ...
# Ошибка при получении навыков для вакансии 118507710: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYGyaMqfkAiyUGAZJoeV3D-E%3D","type":"captcha_required"}],"request_id":"1742439071464e250d2bf12c8cb4ef81"}
# Ошибка при получении навыков для вакансии 117715175: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYLsinq2tCspv21pmfn0bjUo%3D","type":"captcha_required"}],"request_id":"17424390718309578da5d12676959f1d"}
# Ошибка при получении навыков для вакансии 118199211: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYGmS1FkW8vjtv4gE2XHXGq0%3D","type":"captcha_required"}],"request_id":"1742439072218c5275b9b1e1e2278af5"}
# Ошибка при получении навыков для вакансии 118542504: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYGbzew3W-CBGLOg-ICQp614%3D","type":"captcha_required"}],"request_id":"1742439072602449307fdc981e0e8135"}
# Ошибка при получении навыков для вакансии 118558081: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYCFzrlu-m7AeAip-d_m3_DI%3D","type":"captcha_required"}],"request_id":"17424390729934cbfed6bd4b4fe989c8"}
# Ошибка при получении навыков для вакансии 118569320: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYF6dusXFCBON3_PzzuYt-UM%3D","type":"captcha_required"}],"request_id":"17424390738667651e7769b127969ec3"}
# Ошибка при получении навыков для вакансии 118416954: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBhLiC8NwOzCjMXKoxakaUg%3D","type":"captcha_required"}],"request_id":"17424390742778667658c02d202e32bb"}
# Ошибка при получении навыков для вакансии 118506101: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBadjYFClUrmDiGEsDuIsOU%3D","type":"captcha_required"}],"request_id":"174243907466484f5beeeb8aee2de391"}
# Ошибка при получении навыков для вакансии 115948605: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBD4p_sHeGUO71poJm0fVhY%3D","type":"captcha_required"}],"request_id":"1742439075125ded5b0b145977bef86d"}
# Ошибка при получении навыков для вакансии 112987069: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYJTm5Y85HQ_zSENSHnFKD6c%3D","type":"captcha_required"}],"request_id":"1742439075543031f8aed7ef92dca648"}
# Ошибка при получении навыков для вакансии 118513205: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYCh0KyyIA9MQxErTOe4-gIU%3D","type":"captcha_required"}],"request_id":"17424390759295d80805f1600d344da2"}
# Ошибка при получении навыков для вакансии 118142893: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYLRR0TbETOYCfFGd59aC9Hc%3D","type":"captcha_required"}],"request_id":"1742439076306635ce0a25f44bb4584f"}
# Ошибка при получении навыков для вакансии 118439983: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYNP34_-sAPNAqA6Uo1_mTC8%3D","type":"captcha_required"}],"request_id":"1742439076698d270306d81ae5ddaf1c"}
# Ошибка при получении навыков для вакансии 117636408: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYEi4pFixg5A7WzjAMEFh1qg%3D","type":"captcha_required"}],"request_id":"17424390770887d0674ced28f8816128"}
# Ошибка при получении навыков для вакансии 118485139: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYMOfM5q9IGUxGvgcOaWY3Dc%3D","type":"captcha_required"}],"request_id":"17424390774695f639a94737f2f7ab00"}
# Ошибка при получении навыков для вакансии 118459219: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYJHfi7hSaf2C9R3ZD7752eQ%3D","type":"captcha_required"}],"request_id":"17424390778682f8bc3f60bdd3ec431b"}
# Ошибка при получении навыков для вакансии 118155084: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYK1ebJ9pAqwKGVDjLRmA3JE%3D","type":"captcha_required"}],"request_id":"1742439078251ee20c4448e1fcacb881"}
# Ошибка при получении навыков для вакансии 118571847: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYLa50-ntITaWzIKPasaox9k%3D","type":"captcha_required"}],"request_id":"174243907864867a46ecf5c0a00f88c0"}
# Ошибка при получении навыков для вакансии 118545493: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYEXyt-bwqEgGE5zxrZg9-uA%3D","type":"captcha_required"}],"request_id":"17424390790388732d8a65a4072bf585"}
# Ошибка при получении навыков для вакансии 118387838: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYIFZPJHpEUWsEMyb03Zbx8o%3D","type":"captcha_required"}],"request_id":"17424390794326f6a9bec6e5f94e4539"}
# Ошибка при получении навыков для вакансии 118453674: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBg7P0IUm4FROF4gKKFNQS8%3D","type":"captcha_required"}],"request_id":"1742439079822f11c8c235860b914e6a"}
# Ошибка при получении навыков для вакансии 118491158: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYPFtOewTuYNcFEyObYgShHo%3D","type":"captcha_required"}],"request_id":"17424390802028e1559569bb2be0e081"}
# Ошибка при получении навыков для вакансии 117740279: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYHzYcxfVWmRy-SdkSGjpUsE%3D","type":"captcha_required"}],"request_id":"174243908102277cceb5fb99421ba26e"}
# Ошибка при получении навыков для вакансии 118550169: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYFjr97FuP14CzFttXbRPNPU%3D","type":"captcha_required"}],"request_id":"1742439082104487465ae993dd362f40"}
# Ошибка при получении навыков для вакансии 117427373: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBT3yCu9W-Zo1GUoiHtAvZY%3D","type":"captcha_required"}],"request_id":"17424390828902894b50b11d46bd4199"}
# Ошибка при получении навыков для вакансии 118470368: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYDloPn2EicUhsoRA8XJ2erA%3D","type":"captcha_required"}],"request_id":"174243908333323c8c26247f3ed2b099"}
# Ошибка при получении навыков для вакансии 118562169: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYPA1_99QCg5N0-XpYTNx7AE%3D","type":"captcha_required"}],"request_id":"1742439083825eaee645070673a240aa"}
# Ошибка при получении навыков для вакансии 118340290: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYCgEVuS_X7cux1QgOvbDoOQ%3D","type":"captcha_required"}],"request_id":"17424390842193a48e64ad504773a146"}
# Ошибка при получении навыков для вакансии 118470960: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYOp6Rd9jU22vfjffRDWkBj4%3D","type":"captcha_required"}],"request_id":"17424390846165a8ec00d429d1cb6d09"}
# Ошибка при получении навыков для вакансии 118312576: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYC_hflSCsyIQiR675zYxvUs%3D","type":"captcha_required"}],"request_id":"1742439085021628f723b47147296eeb"}
# Ошибка при получении навыков для вакансии 118253837: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYET5bMoSFu-PKF1HjVk7Fzo%3D","type":"captcha_required"}],"request_id":"1742439085454bfe547d498a5bdab332"}
# Ошибка при получении навыков для вакансии 118260448: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYNT4hmeUMjQLwTPOWFqaD4Y%3D","type":"captcha_required"}],"request_id":"1742439085868c434d304fd0570626fa"}
# Ошибка при получении навыков для вакансии 118572437: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBhZgHV5Y61K_FjYnIDaQBg%3D","type":"captcha_required"}],"request_id":"1742439086288392fb051e67b23cebea"}
# Ошибка при получении навыков для вакансии 118342335: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYKunPUU8xdzqxIgn-qT-Owc%3D","type":"captcha_required"}],"request_id":"1742439086683a041faebba4454049ab"}
# Ошибка при получении навыков для вакансии 118449405: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYDCj8WdOUO3fjmkkAi90gA4%3D","type":"captcha_required"}],"request_id":"1742439087969eba0aa5daa68f12ea97"}
# Ошибка при получении навыков для вакансии 118312256: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYHhlUW4IG8yrLmebNMbOikI%3D","type":"captcha_required"}],"request_id":"174243908838861c57f2248f8a48bebb"}
# Ошибка при получении навыков для вакансии 118543517: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYA-CP-GrUMsVeRBklNVn9W8%3D","type":"captcha_required"}],"request_id":"17424390892405e2ecc7e71a2af17f33"}
# Ошибка при получении навыков для вакансии 117052813: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYDiaY-y1HhPFERL8YasdLBM%3D","type":"captcha_required"}],"request_id":"1742439090244902ba312e4cd9d49a55"}
# Ошибка при получении навыков для вакансии 118525867: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYM3SJmrYKRJRXBesvjef_l4%3D","type":"captcha_required"}],"request_id":"174243909105088a2a1b4d87a979644f"}
# Ошибка при получении навыков для вакансии 118556831: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYP7sXxc1qUadjmLVNKAA95E%3D","type":"captcha_required"}],"request_id":"17424390914416f5de32a8e6f0d6e277"}
# Ошибка при получении навыков для вакансии 118467230: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYIpP6ukp1Jl5YRKy6m8Wcuc%3D","type":"captcha_required"}],"request_id":"1742439092310db0ed0152ff0e7791b7"}
# Ошибка при получении навыков для вакансии 118494315: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYMrpPijnwaiQ6Zp05jVFtNI%3D","type":"captcha_required"}],"request_id":"1742439093327dc235e804fa5f27b7ca"}
# Ошибка при получении навыков для вакансии 118507323: 403, {"errors":[{"value":"captcha_required","captcha_url":"https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFmUA3SFZr_Pa4yXPQEusAiTHBc8_LWa626j-S227_PWg9_aifZ2ny8O96aapoJBqYBk0RxVYy0CqGpemrOOTSX4%3D","type":"captcha_required"}],"request_id":"174243909423361aa4ec128fbb39f94e"}
# DataFrame с вакансиями:
#           id                                               name  \
# 0  118550274     Ведущий специалист по подбору персонала (офис)
# 1  118460000                                    QA engineer DWH
# 2  118524897  Junior Data Scientist / Machine Learning Engineer
# 3  118567600       Стажер аналитик / разработчик (SQL / Python)
# 4  118567601       Стажер аналитик / разработчик (SQL / Python)
#
#                      employer salary_from          experience  \
# 0                      Гознак  Не указано       От 3 до 6 лет
# 1              Ренессанс Банк  Не указано  От 1 года до 3 лет
# 2  Титов Дмитрий Владимирович      150000           Нет опыта
# 3            КОРУС Консалтинг  Не указано           Нет опыта
# 4            КОРУС Консалтинг  Не указано           Нет опыта
#
#                                          description      published_at
# 0  Что хотим видеть у кандидата: - успешный опыт ...  2025-03-19 12:12
# 1  Высшее техническое образование. Опыт проведени...  2025-03-17 16:05
# 2  Навыки работы с системами контроля версий (Git...  2025-03-18 20:14
# 3  Ты в том числе учишься на 3-4 курсе бакалавриа...  2025-03-19 16:32
# 4  Ты учишься на 3-4 курсе бакалавриата или 1-2 к...  2025-03-19 16:32
#
# DataFrame с навыками:
#   vacancy_id                skill
# 0  118550274     Подбор персонала
# 1  118550274  Адаптация персонала
# 2  118550274         Прямой поиск
# 3  118550274    Оценка кандидатов
# 4  118550274       IT Recruitment

# %%
df_vacancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            600 non-null    object
#  1   name          600 non-null    object
#  2   employer      600 non-null    object
#  3   salary_from   600 non-null    object
#  4   experience    600 non-null    object
#  5   description   597 non-null    object
#  6   published_at  600 non-null    object
# dtypes: object(7)
# memory usage: 32.9+ KB

# %%
df_vacancys = df_vacancy.copy()
df_vacancy_skillss = df_vacancy_skills.copy()

# %%
df_vacancy = df_vacancy.drop_duplicates(subset=['id'])

# %%
df_vacancy_skills
# Out:
#      vacancy_id                skill
# 0     118550274     Подбор персонала
# 1     118550274  Адаптация персонала
# 2     118550274         Прямой поиск
# 3     118550274    Оценка кандидатов
# 4     118550274       IT Recruitment
# ...         ...                  ...
# 1956  118468826                Flask
# 1957  118468826              FastAPI
# 1958  118468826                  ORM
# 1959  118468826                MySQL
# 1960  118468826             REST API
#
# [1961 rows x 2 columns]

# %%
unique_skills = df_vacancy_skills['skill'].unique()
data_unique_skill = {'skill': unique_skills}
df_unique_skill = pd.DataFrame(data_unique_skill)
df_unique_skill['id'] = range(1, len(df_unique_skill) + 1) # Создаем новый id для каждого уникального навыка
df_unique_skill = df_unique_skill[['id', 'skill']]  # Меняем порядок столбцов
print("df_unique_skill:\n", df_unique_skill)
# Out:
# df_unique_skill:
#        id                skill
# 0      1     Подбор персонала
# 1      2  Адаптация персонала
# 2      3         Прямой поиск
# 3      4    Оценка кандидатов
# 4      5       IT Recruitment
# ..   ...                  ...
# 810  811          Google Docs
# 811  812     Удаленная работа
# 812  813              продажи
# 813  814         маркетплейсы
# 814  815            аналитика
#
# [815 rows x 2 columns]

# %%
df_merged = pd.merge(df_vacancy_skills, df_unique_skill, on='skill', how='left')

# 2. Замена столбца 'skill' в df_skill на значения из столбца 'id' из df_unique_skill
#  Столбец skill будет перезаписан id соответствующего навыка
df_vacancy_skills['skill'] = df_merged['id']

# %%
df_vacancy_skills.insert(0, 'id', range(1, len(df_vacancy_skills) + 1))
df_vacancy_skills = df_vacancy_skills.rename(columns={'skill': 'skill_id'})
df_vacancy_skills
# Out:
#         id vacancy_id  skill_id
# 0        1  118550274         1
# 1        2  118550274         2
# 2        3  118550274         3
# 3        4  118550274         4
# 4        5  118550274         5
# ...    ...        ...       ...
# 1956  1957  118468826        39
# 1957  1958  118468826        40
# 1958  1959  118468826        41
# 1959  1960  118468826        42
# 1960  1961  118468826        22
#
# [1961 rows x 3 columns]

# %%
df_unique_skill
# Out:
#       id                skill
# 0      1     Подбор персонала
# 1      2  Адаптация персонала
# 2      3         Прямой поиск
# 3      4    Оценка кандидатов
# 4      5       IT Recruitment
# ..   ...                  ...
# 810  811          Google Docs
# 811  812     Удаленная работа
# 812  813              продажи
# 813  814         маркетплейсы
# 814  815            аналитика
#
# [815 rows x 2 columns]

# %%
df_vacancy
# Out:
#             id                                               name  \
# 0    118550274     Ведущий специалист по подбору персонала (офис)
# 1    118460000                                    QA engineer DWH
# 2    118524897  Junior Data Scientist / Machine Learning Engineer
# 3    118567600       Стажер аналитик / разработчик (SQL / Python)
# 4    118567601       Стажер аналитик / разработчик (SQL / Python)
# ..         ...                                                ...
# 589  117406897                      Менеджер по работе с отзывами
# 592  118512914                             Директор по маркетингу
# 593  118276879    Графический дизайнер контента для маркетплейсов
# 594  118331694                  Менеджер продукта/Product manager
# 596  118424761                               Менеджер по закупкам
#
#                        employer salary_from          experience  \
# 0                        Гознак  Не указано       От 3 до 6 лет
# 1                Ренессанс Банк  Не указано  От 1 года до 3 лет
# 2    Титов Дмитрий Владимирович      150000           Нет опыта
# 3              КОРУС Консалтинг  Не указано           Нет опыта
# 4              КОРУС Консалтинг  Не указано           Нет опыта
# ..                          ...         ...                 ...
# 589           Smirnov.Marketing       30000           Нет опыта
# 592               Concept Group  Не указано       От 3 до 6 лет
# 593      Мартюченко Ян Игоревич       80000  От 1 года до 3 лет
# 594                 Лит Энерджи  Не указано       От 3 до 6 лет
# 596                  Dr. Bakers  Не указано       От 3 до 6 лет
#
#                                            description      published_at
# 0    Что хотим видеть у кандидата: - успешный опыт ...  2025-03-19 12:12
# 1    Высшее техническое образование. Опыт проведени...  2025-03-17 16:05
# 2    Навыки работы с системами контроля версий (Git...  2025-03-18 20:14
# 3    Ты в том числе учишься на 3-4 курсе бакалавриа...  2025-03-19 16:32
# 4    Ты учишься на 3-4 курсе бакалавриата или 1-2 к...  2025-03-19 16:32
# ..                                                 ...               ...
# 589  Вы умеете обрабатывать возражения клиентов. Вы...  2025-02-18 11:09
# 592  Высшее профильное образование. Аналогичный опы...  2025-03-18 15:47
# 593  Внимательность к деталям и способность работат...  2025-03-13 08:52
# 594  Опыт вывода новых продуктов на рынок. Навык по...  2025-03-14 10:29
# 596  Высшее образование. Опыт работы в закупках от ...  2025-03-17 10:47
#
# [560 rows x 7 columns]

# %%
import pandas as pd
from sqlalchemy import create_engine, Column, Integer, String, Float, DateTime, ForeignKey
from sqlalchemy.orm import declarative_base, relationship, sessionmaker
from sqlalchemy.dialects.postgresql import UUID
import uuid

# Параметры подключения к PostgreSQL
db_user = "sqlmaster"
db_password = "VOf67bY6kR"
db_host = "92.63.177.19"
db_name = "hh_ithub_msod"
schema_name = "jobsearch"

# Формируем строку подключения
db_string = f"postgresql://{db_user}:{db_password}@{db_host}/{db_name}"

# Создаем движок SQLAlchemy
engine = create_engine(db_string)

# Создаем базовый класс для моделей
Base = declarative_base()

# %%
import pandas as pd
from sqlalchemy import create_engine, Column, Integer, String, Float, DateTime, ForeignKey
from sqlalchemy.orm import declarative_base, relationship, sessionmaker
from sqlalchemy.dialects.postgresql import UUID
import uuid

# Параметры подключения к PostgreSQL
db_user = "sqlmaster"
db_password = "VOf67bY6kR"
db_host = "92.63.177.19"
db_name = "hh_ithub_msod"
schema_name = "jobsearch"

# Формируем строку подключения
db_string = f"postgresql://{db_user}:{db_password}@{db_host}/{db_name}"

# Создаем движок SQLAlchemy
engine = create_engine(db_string)

# Создаем базовый класс для моделей
Base = declarative_base()


class Vacancy(Base):
    __tablename__ = 'vacancies'
    __table_args__ = {'schema': schema_name}

    id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(String)
    employer = Column(String)
    salary_from = Column(String)
    experience = Column(String)
    description = Column(String)
    published_at = Column(DateTime)

    vacancy_skills = relationship("VacancySkill", back_populates="vacancy")

class UniqueSkill(Base):
    __tablename__ = 'skills'
    __table_args__ = {'schema': schema_name}

    id = Column(Integer, primary_key=True, autoincrement=True)
    skill = Column(String(255), nullable=False, unique=True)

    vacancy_skills = relationship("VacancySkill", back_populates="skill")
    student_skills = relationship("StudentSkill", back_populates="skill")

class VacancySkill(Base):
    __tablename__ = 'vacancy_skills'
    __table_args__ = {'schema': schema_name}

    id = Column(Integer, primary_key=True, autoincrement=True)
    vacancy_id = Column(Integer, ForeignKey(f'{schema_name}.vacancies.id', ondelete='CASCADE'), nullable=False)
    skill_id = Column(Integer, ForeignKey(f'{schema_name}.skills.id', ondelete='CASCADE'), nullable=False)

    vacancy = relationship("Vacancy", back_populates="vacancy_skills")
    skill = relationship("UniqueSkill", back_populates="vacancy_skills")

class Students(Base):
    __tablename__ = 'students'
    __table_args__ = {'schema': schema_name}

    id = Column(Integer, primary_key=True, autoincrement=True)
    full_name = Column(String(255), nullable=False)

    student_skills = relationship("StudentSkill", back_populates="student")

class StudentSkill(Base):
    __tablename__ = 'student_skills'
    __table_args__ = {'schema': schema_name}

    id = Column(Integer, primary_key=True, autoincrement=True)
    student_id = Column(Integer, ForeignKey(f'{schema_name}.students.id', ondelete='CASCADE'), nullable=False)
    skill_id = Column(Integer, ForeignKey(f'{schema_name}.skills.id', ondelete='CASCADE'), nullable=False)

    student = relationship("Students", back_populates="student_skills")
    skill = relationship("UniqueSkill", back_populates="student_skills")

Base.metadata.create_all(engine)

# %%
vacancy_data = df_vacancy.to_dict(orient='records')

skill_data = df_vacancy_skills.to_dict(orient='records')

skill_unique_data = df_unique_skill.to_dict(orient='records')


# Создание сессии SQLAlchemy
Session = sessionmaker(bind=engine)
session = Session()

# Добавление данных в таблицу vacancies
vacancies = [Vacancy(**vacancy) for vacancy in vacancy_data]
session.add_all(vacancies)

# Добавление данных в таблицу skills
skills = [UniqueSkill(**skill) for skill in skill_unique_data]
session.add_all(skills)

skills_vacancy = [VacancySkill(**skill) for skill in skill_data]
session.add_all(skills_vacancy)

# Фиксация изменений и закрытие сессии
session.commit()
session.close()

print("Данные успешно загружены в базу данных!")
# Out:
# Данные успешно загружены в базу данных!

# %%
# Сохранение данных из df_vacancy в CSV
df_vacancy.to_csv('vacancies.csv', index=False, encoding='utf-8')

# Сохранение данных из df_vacancy_skills в CSV
df_vacancy_skills.to_csv('vacancy_skills.csv', index=False, encoding='utf-8')

# Сохранение данных из df_unique_skill в CSV
df_unique_skill.to_csv('unique_skills.csv', index=False, encoding='utf-8')

print("Данные успешно сохранены в CSV файлы!")
# Out:
# Данные успешно сохранены в CSV файлы!

# %%
import pandas as pd
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker

# Параметры подключения к базе данных
db_user = "sqlmaster"
db_password = "VOf67bY6kR"
db_host = "92.63.177.19"
db_name = "hh_ithub_msod"
schema_name = "jobsearch"

# Создаем движок для подключения к базе данных
db_string = f"postgresql://{db_user}:{db_password}@{db_host}/{db_name}"
engine = create_engine(db_string)

# Создаем класс "Session" для сессий с базой данных
Session = sessionmaker(bind=engine)
# Создаем сессию
session = Session()

# Запрашиваем и экспортируем данные из таблицы Vacancies
vacancies_query = session.execute(text(f"SELECT * FROM {schema_name}.vacancies"))
vacancies_df = pd.DataFrame(vacancies_query.fetchall(), columns=vacancies_query.keys())
vacancies_df.to_csv('vacancies_export.csv', index=False)

# Запрашиваем и экспортируем данные из таблицы Skills
skills_query = session.execute(text(f"SELECT * FROM {schema_name}.skills"))
skills_df = pd.DataFrame(skills_query.fetchall(), columns=skills_query.keys())
skills_df.to_csv('skills_export.csv', index=False)

# Запрашиваем и экспортируем данные из таблицы Vacancy Skills
vacancy_skills_query = session.execute(text(f"SELECT * FROM {schema_name}.vacancy_skills"))
vacancy_skills_df = pd.DataFrame(vacancy_skills_query.fetchall(), columns=vacancy_skills_query.keys())
vacancy_skills_df.to_csv('vacancy_skills_export.csv', index=False)

# Запрашиваем и экспортируем данные из таблицы Students
students_query = session.execute(text(f"SELECT * FROM {schema_name}.students"))
students_df = pd.DataFrame(students_query.fetchall(), columns=students_query.keys())
students_df.to_csv('students_export.csv', index=False)

# Запрашиваем и экспортируем данные из таблицы Student Skills
student_skills_query = session.execute(text(f"SELECT * FROM {schema_name}.student_skills"))
student_skills_df = pd.DataFrame(student_skills_query.fetchall(), columns=student_skills_query.keys())
student_skills_df.to_csv('student_skills_export.csv', index=False)

# Закрываем сессию
session.close()

print("Данные успешно экспортированы в файлы CSV.")
# Out:
# Данные успешно экспортированы в файлы CSV.
